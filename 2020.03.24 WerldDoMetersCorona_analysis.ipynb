# %% [markdown]
# __Example:__
#
# Gather the all Municipalities name

# %%
import requests
import pandas as pd
from datetime import date, timedelta 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#importing the corona aatal van de landen
#df = pd.read_csv('output/corona.csv',index_col=0)
df = pd.read_csv('output/corona_dailyNewCases.csv',index_col=0)
df
# Out:
#           date  Italy    USA  Spain  Germany  France  Switzerland    UK  \
# 0   02/15/2020      0      0      0        0       0            0     0
# 1   02/16/2020      0      0      0        0       0            0     0
# 2   02/17/2020      0      0      0        0       0            0     0
# 3   02/18/2020      0      0      0        0       0            0     0
# 4   02/19/2020      0      0      0        0       0            0     0
# ..         ...    ...    ...    ...      ...     ...          ...   ...
# 67  04/25/2020   2357  35419   3995     1514    1660          217  4913
# 68  04/28/2020   1739  23196   2793      988    1173          103  4309
# 69  04/29/2020   2086  28429   4771     1627     509          143  4076
# 70  05/01/2020   1965  36007   3648     1068     168          119  6201
# 71  05/02/2020   1900  29744   2588      890    1050          112  4806
#
#     Netherlands
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ..          ...
# 67          655
# 68          400
# 69          386
# 70          475
# 71          445
#
# [72 rows x 9 columns]

# %%
df1 = df
df1
# Out:
#           date  Italy    USA  Spain  Germany  France  Switzerland    UK  \
# 0   02/15/2020      0      0      0        0       0            0     0
# 1   02/16/2020      0      0      0        0       0            0     0
# 2   02/17/2020      0      0      0        0       0            0     0
# 3   02/18/2020      0      0      0        0       0            0     0
# 4   02/19/2020      0      0      0        0       0            0     0
# ..         ...    ...    ...    ...      ...     ...          ...   ...
# 67  04/25/2020   2357  35419   3995     1514    1660          217  4913
# 68  04/28/2020   1739  23196   2793      988    1173          103  4309
# 69  04/29/2020   2086  28429   4771     1627     509          143  4076
# 70  05/01/2020   1965  36007   3648     1068     168          119  6201
# 71  05/02/2020   1900  29744   2588      890    1050          112  4806
#
#     Netherlands
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ..          ...
# 67          655
# 68          400
# 69          386
# 70          475
# 71          445
#
# [72 rows x 9 columns]

# %%
populations=[60480000,327200000,46660000,82790000,66890000,8560000,66440000,17180000]
i=0
for column in df.drop('date', axis=1):
    df1[column]= (df1[column].astype(int))/populations[i]
    i+=1
df1
# Out:
#           date     Italy       USA     Spain   Germany    France  Switzerland  \
# 0   02/15/2020  0.000000  0.000000  0.000000  0.000000  0.000000     0.000000
# 1   02/16/2020  0.000000  0.000000  0.000000  0.000000  0.000000     0.000000
# 2   02/17/2020  0.000000  0.000000  0.000000  0.000000  0.000000     0.000000
# 3   02/18/2020  0.000000  0.000000  0.000000  0.000000  0.000000     0.000000
# 4   02/19/2020  0.000000  0.000000  0.000000  0.000000  0.000000     0.000000
# ..         ...       ...       ...       ...       ...       ...          ...
# 67  04/25/2020  0.000039  0.000108  0.000086  0.000018  0.000025     0.000025
# 68  04/28/2020  0.000029  0.000071  0.000060  0.000012  0.000018     0.000012
# 69  04/29/2020  0.000034  0.000087  0.000102  0.000020  0.000008     0.000017
# 70  05/01/2020  0.000032  0.000110  0.000078  0.000013  0.000003     0.000014
# 71  05/02/2020  0.000031  0.000091  0.000055  0.000011  0.000016     0.000013
#
#           UK  Netherlands
# 0   0.000000     0.000000
# 1   0.000000     0.000000
# 2   0.000000     0.000000
# 3   0.000000     0.000000
# 4   0.000000     0.000000
# ..       ...          ...
# 67  0.000074     0.000038
# 68  0.000065     0.000023
# 69  0.000061     0.000022
# 70  0.000093     0.000028
# 71  0.000072     0.000026
#
# [72 rows x 9 columns]

# %%
df1.to_csv('output/corona%.csv')

# %%
#plt.style.use('fivethirtyeight')
plt.style.use('seaborn-darkgrid')
my_dpi=96
plt.figure(figsize=(1080/my_dpi, 200/my_dpi), dpi=my_dpi)
 
# plot
#plt.plot( 'date', 'Netherlands', data=df)
plt.plot( 'date', 'Netherlands', data=df1)
plt.show()

# %%
#plt.style.use('fivethirtyeight')
def plott(column):
    #plt.style.use('fivethirtyeight')
    plt.style.use('seaborn-darkgrid')
    my_dpi=96
    plt.figure(figsize=(16,2), dpi=my_dpi)
    # plot    
    plt.plot( 'date', column, data=df1,)
    plt.plot( 'date', 'Netherlands', data=df1)
    print(column + ' & Netherlands --- Comparison of Daily Cases by Population')
    plt.show()

# %%
for column in df1.drop('date', axis=1):
    plott(column)
# Out:
# Italy & Netherlands --- Comparison of Daily Cases by Population
# USA & Netherlands --- Comparison of Daily Cases by Population
# Spain & Netherlands --- Comparison of Daily Cases by Population
# Germany & Netherlands --- Comparison of Daily Cases by Population
# France & Netherlands --- Comparison of Daily Cases by Population
# Switzerland & Netherlands --- Comparison of Daily Cases by Population
# UK & Netherlands --- Comparison of Daily Cases by Population
# Netherlands & Netherlands --- Comparison of Daily Cases by Population

# %%
# Draw Plot
plt.figure(figsize=(16,5), dpi= 80)
for column in df1.drop('date', axis=1):
    sns.kdeplot(df1[column], shade=False,alpha=.9)

# Decoration
plt.title('Density Plot of City Mileage by n_Cylinders', fontsize=22)
#plt.legend()
plt.show()

# %%
# Draw Plot
def Density(column):
    plt.figure(figsize=(16,2), dpi= 80)
    sns.kdeplot(df1[column], shade=False,alpha=.9)
    sns.kdeplot(df1['Netherlands'], shade=False,alpha=.9)
    # Decoration
    plt.title('Density Plot of ' + str(column), fontsize=12)
    #plt.legend()
    plt.show()

# %%
for column in df1.drop('date', axis=1):
    Density(column)
