# %% [markdown]
# __Example:__
#
# Gather the all Municipalities name

# %%
import requests
import pandas as pd
from datetime import date, timedelta 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#importing the corona aatal van de landen
#df = pd.read_csv('output/corona.csv',index_col=0)
df = pd.read_csv('output/corona_dailyNewCases.csv',index_col=0)
df
# Out:
#           date  Italy    USA  Spain  Germany  France  Switzerland    UK  \
# 0   02/15/2020      0      0      0        0       0            0     0
# 1   02/16/2020      0      0      0        0       0            0     0
# 2   02/17/2020      0      0      0        0       0            0     0
# 3   02/18/2020      0      0      0        0       0            0     0
# 4   02/19/2020      0      0      0        0       0            0     0
# ..         ...    ...    ...    ...      ...     ...          ...   ...
# 60  04/17/2020   3493  32165   5891     3699    1909          346  5599
# 61  04/18/2020   3491  29057   3577     2327    3824          326  5525
# 62  04/19/2020   3047  25844   4258     2018    1101          336  5850
# 63  04/20/2020   2256  28123   1536     1323    2489          204  4676
# 64  04/21/2020   2729  25985   3968     1388    2667          119  4301
#
#     Netherlands
# 0             0
# 1             0
# 2             0
# 3             0
# ...

# %%
df1 = df
df1
# Out:
#           date  Italy    USA  Spain  Germany  France  Switzerland    UK  \
# 0   02/15/2020      0      0      0        0       0            0     0
# 1   02/16/2020      0      0      0        0       0            0     0
# 2   02/17/2020      0      0      0        0       0            0     0
# 3   02/18/2020      0      0      0        0       0            0     0
# 4   02/19/2020      0      0      0        0       0            0     0
# ..         ...    ...    ...    ...      ...     ...          ...   ...
# 60  04/17/2020   3493  32165   5891     3699    1909          346  5599
# 61  04/18/2020   3491  29057   3577     2327    3824          326  5525
# 62  04/19/2020   3047  25844   4258     2018    1101          336  5850
# 63  04/20/2020   2256  28123   1536     1323    2489          204  4676
# 64  04/21/2020   2729  25985   3968     1388    2667          119  4301
#
#     Netherlands
# 0             0
# 1             0
# 2             0
# 3             0
# ...

# %%
populations=[60480000,327200000,46660000,82790000,66890000,8560000,66440000,17180000]
i=0
for column in df.drop('date', axis=1):
    df1[column]= (df1[column].astype(int))/populations[i]
    i+=1
df1
# Out:
#           date     Italy       USA     Spain   Germany    France  Switzerland  \
# 0   02/15/2020  0.000000  0.000000  0.000000  0.000000  0.000000     0.000000
# 1   02/16/2020  0.000000  0.000000  0.000000  0.000000  0.000000     0.000000
# 2   02/17/2020  0.000000  0.000000  0.000000  0.000000  0.000000     0.000000
# 3   02/18/2020  0.000000  0.000000  0.000000  0.000000  0.000000     0.000000
# 4   02/19/2020  0.000000  0.000000  0.000000  0.000000  0.000000     0.000000
# ..         ...       ...       ...       ...       ...       ...          ...
# 60  04/17/2020  0.000058  0.000098  0.000126  0.000045  0.000029     0.000040
# 61  04/18/2020  0.000058  0.000089  0.000077  0.000028  0.000057     0.000038
# 62  04/19/2020  0.000050  0.000079  0.000091  0.000024  0.000016     0.000039
# 63  04/20/2020  0.000037  0.000086  0.000033  0.000016  0.000037     0.000024
# 64  04/21/2020  0.000045  0.000079  0.000085  0.000017  0.000040     0.000014
#
#           UK  Netherlands
# ...

# %%
df1.to_csv('output/corona%.csv')

# %%
#plt.style.use('fivethirtyeight')
plt.style.use('seaborn-darkgrid')
my_dpi=96
plt.figure(figsize=(1080/my_dpi, 200/my_dpi), dpi=my_dpi)
 
# plot
#plt.plot( 'date', 'Netherlands', data=df)
plt.plot( 'date', 'Netherlands', data=df1)
plt.show()

# %%
for column in df.drop('date', axis=1):
    sns.relplot(x="date", y=column, data=df1)

# %%
#plt.style.use('fivethirtyeight')
def plott(column):
    #plt.style.use('fivethirtyeight')
    plt.style.use('seaborn-darkgrid')
    my_dpi=96
    plt.figure(figsize=(16,2), dpi=my_dpi)
    # plot    
    plt.plot( 'date', column, data=df1,)
    plt.plot( 'date', 'Netherlands', data=df1)
    plt.show()

# %%
for column in df1.drop('date', axis=1):
    plott(column)

# %%
# Draw Plot
plt.figure(figsize=(16,5), dpi= 80)
for column in df1.drop('date', axis=1):
    sns.kdeplot(df1[column], shade=False,alpha=.9)

# Decoration
plt.title('Density Plot of City Mileage by n_Cylinders', fontsize=22)
#plt.legend()
plt.show()

# %%
# Draw Plot
def Density(column):
    plt.figure(figsize=(16,2), dpi= 80)
    sns.kdeplot(df1[column], shade=False,alpha=.9)
    sns.kdeplot(df1['Netherlands'], shade=False,alpha=.9)
    # Decoration
    plt.title('Density Plot of ' + str(column), fontsize=12)
    #plt.legend()
    plt.show()

# %%
for column in df1.drop('date', axis=1):
    Density(column)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})

# Create the data
rs = np.random.RandomState(1979)
x = rs.randn(500)
g = np.tile(list("ABCDEFGHIJ"), 50)
df = pd.DataFrame(dict(x=x, g=g))
m = df.g.map(ord)
df["x"] += m

# Initialize the FacetGrid object
pal = sns.cubehelix_palette(10, rot=-.25, light=.7)
g = sns.FacetGrid(df, row="g", hue="g", aspect=15, height=.5, palette=pal)

# Draw the densities in a few steps
g.map(sns.kdeplot, "x", clip_on=False, shade=True, alpha=1, lw=1.5, bw=.2)
g.map(sns.kdeplot, "x", clip_on=False, color="w", lw=2, bw=.2)
g.map(plt.axhline, y=0, lw=2, clip_on=False)


# Define and use a simple function to label the plot in axes coordinates
def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, fontweight="bold", color=color,
            ha="left", va="center", transform=ax.transAxes)


g.map(label, "x")

# Set the subplots to overlap
g.fig.subplots_adjust(hspace=-.25)

# Remove axes details that don't play well with overlap
g.set_titles("")
g.set(yticks=[])
g.despine(bottom=True, left=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:848: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   self.fig.tight_layout()

# %%
# !pip install joypy
# Import Data
#mpg = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")

# Draw Plot
#plt.figure(figsize=(16,10), dpi= 80)
fig, axes = joypy.joyplot(df1, column in df1.drop('date', axis=1), ylim='own', figsize=(14,10))

# Decoration
plt.title('Joy Plot of City and Highway Mileage by Class', fontsize=22)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-dbb8ce8d52c2> in <module>
#       5 # Draw Plot
#       6 #plt.figure(figsize=(16,10), dpi= 80)
# ----> 7 fig, axes = joypy.joyplot(df1, column in df1.drop('date', axis=1), ylim='own', figsize=(14,10))
#       8
#       9 # Decoration
#
# NameError: name 'joypy' is not defined
